# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing data
train_data = pd.read_csv('train.csv')
print(train_data.shape)
train_data.head(7)
# Out:
# (136950, 6)
#    id        date    country         store  \
# 0   0  2017-01-01  Argentina  Kaggle Learn
# 1   1  2017-01-01  Argentina  Kaggle Learn
# 2   2  2017-01-01  Argentina  Kaggle Learn
# 3   3  2017-01-01  Argentina  Kaggle Learn
# 4   4  2017-01-01  Argentina  Kaggle Learn
# 5   5  2017-01-01  Argentina  Kaggle Store
# 6   6  2017-01-01  Argentina  Kaggle Store
#
#                                           product  num_sold
# 0               Using LLMs to Improve Your Coding        63
# 1                   Using LLMs to Train More LLMs        66
# 2  Using LLMs to Win Friends and Influence People         9
# 3      Using LLMs to Win More Kaggle Competitions        59
# 4                      Using LLMs to Write Better        49
# 5               Using LLMs to Improve Your Coding        88
# 6                   Using LLMs to Train More LLMs        98

# %%
# check null values
train_data.isna().sum()
# Out:
# id          0
# date        0
# country     0
# store       0
# product     0
# num_sold    0
# dtype: int64

# %%
# check duplicates for non-id columns
train_data.drop('id',axis=1).duplicated().sum()
# Out:
# 0

# %%
# statistical descriptions of all columns
train_data.describe(include='all')
# Out:
#                   id        date    country         store  \
# count   136950.00000      136950     136950        136950
# unique           NaN        1826          5             3
# top              NaN  2017-01-01  Argentina  Kaggle Learn
# freq             NaN          75      27390         45650
# mean     68474.50000         NaN        NaN           NaN
# std      39534.20402         NaN        NaN           NaN
# min          0.00000         NaN        NaN           NaN
# 25%      34237.25000         NaN        NaN           NaN
# 50%      68474.50000         NaN        NaN           NaN
# 75%     102711.75000         NaN        NaN           NaN
# max     136949.00000         NaN        NaN           NaN
#
#                                   product       num_sold
# count                              136950  136950.000000
# unique                                  5            NaN
# top     Using LLMs to Improve Your Coding            NaN
# ...

# %%
set(train_data['country'])
# Out:
# {'Argentina', 'Canada', 'Estonia', 'Japan', 'Spain'}

# %% [markdown]
# ## Importing country codes

# %%
train_data.loc[train_data['country']=='Argentina','country_code'] = 'AR'
train_data.loc[train_data['country']=='Canada','country_code'] = 'CA'
train_data.loc[train_data['country']=='Estonia','country_code'] = 'EE'
train_data.loc[train_data['country']=='Japan','country_code'] = 'JP'
train_data.loc[train_data['country']=='Spain','country_code'] = 'ES'
train_data
# Out:
#             id        date    country         store  \
# 0            0  2017-01-01  Argentina  Kaggle Learn
# 1            1  2017-01-01  Argentina  Kaggle Learn
# 2            2  2017-01-01  Argentina  Kaggle Learn
# 3            3  2017-01-01  Argentina  Kaggle Learn
# 4            4  2017-01-01  Argentina  Kaggle Learn
# ...        ...         ...        ...           ...
# 136945  136945  2021-12-31      Spain     Kagglazon
# 136946  136946  2021-12-31      Spain     Kagglazon
# 136947  136947  2021-12-31      Spain     Kagglazon
# 136948  136948  2021-12-31      Spain     Kagglazon
# 136949  136949  2021-12-31      Spain     Kagglazon
#
#                                                product  num_sold country_code
# 0                    Using LLMs to Improve Your Coding        63           AR
# 1                        Using LLMs to Train More LLMs        66           AR
# 2       Using LLMs to Win Friends and Influence People         9           AR
# ...

# %% [markdown]
# ## Creating date features

# %%
def create_dateFeature(df):
    df['Year_Nb'] = (df.date.dt.year - self.strt_year).astype(np.int8);
    df['Qtr_Nb'] = df['date'].dt.quarter.astype(np.int8);
    df["Month_Nb"] = df["date"].dt.month.astype(np.int8);
    df["Month_Sin"] = (np.sin(df['Month_Nb'] * (2 * np.pi / 12))).astype(np.float32);
    df["Day_Nb"] = df["date"].dt.day.astype(np.int16);
    df["Day_Sin"] = (np.sin(df['Day_Nb'] * (2 * np.pi / 12))).astype(np.float32);
    df["Weekday_Nb"] = df["date"].dt.dayofweek.astype(np.int8);
    df['Week_Nb'] = np.clip(df['date'].dt.week, a_min = 0, a_max= 52);
    df['Is_Weekend'] = np.where(df['Weekday_Nb'] >= 5,1,0);
