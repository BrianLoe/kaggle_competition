# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# SMAPE Calculator (competition-metric taken from geeksforgeeks)
def calculate_smape(actual, predicted) -> float:
  
    # Convert actual and predicted to numpy
    # array data type if not already
    if not all([isinstance(actual, np.ndarray), 
                isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual),
        np.array(predicted)
  
    return round(
        np.mean(
            np.abs(predicted - actual) / 
            ((np.abs(predicted) + np.abs(actual))/2)
        )*100, 4
    )

# %%
from dateutil.easter import easter
from datetime import datetime, date, timedelta
import holidays
from holidays import CountryHoliday

# %%
train_data_ori = pd.read_csv('train.csv')
train_data_ori
# Out:
#             id        date    country         store  \
# 0            0  2017-01-01  Argentina  Kaggle Learn
# 1            1  2017-01-01  Argentina  Kaggle Learn
# 2            2  2017-01-01  Argentina  Kaggle Learn
# 3            3  2017-01-01  Argentina  Kaggle Learn
# 4            4  2017-01-01  Argentina  Kaggle Learn
# ...        ...         ...        ...           ...
# 136945  136945  2021-12-31      Spain     Kagglazon
# 136946  136946  2021-12-31      Spain     Kagglazon
# 136947  136947  2021-12-31      Spain     Kagglazon
# 136948  136948  2021-12-31      Spain     Kagglazon
# 136949  136949  2021-12-31      Spain     Kagglazon
#
#                                                product  num_sold
# 0                    Using LLMs to Improve Your Coding        63
# 1                        Using LLMs to Train More LLMs        66
# 2       Using LLMs to Win Friends and Influence People         9
# 3           Using LLMs to Win More Kaggle Competitions        59
# 4                           Using LLMs to Write Better        49
# ...                                                ...       ...
# 136945               Using LLMs to Improve Your Coding       700
# 136946                   Using LLMs to Train More LLMs       752
# 136947  Using LLMs to Win Friends and Influence People       111
# 136948      Using LLMs to Win More Kaggle Competitions       641
# 136949                      Using LLMs to Write Better       539
#
# [136950 rows x 6 columns]

# %%
test_data_ori = pd.read_csv('test.csv')
test_data_ori
# Out:
#            id        date    country         store  \
# 0      136950  2022-01-01  Argentina  Kaggle Learn
# 1      136951  2022-01-01  Argentina  Kaggle Learn
# 2      136952  2022-01-01  Argentina  Kaggle Learn
# 3      136953  2022-01-01  Argentina  Kaggle Learn
# 4      136954  2022-01-01  Argentina  Kaggle Learn
# ...       ...         ...        ...           ...
# 27370  164320  2022-12-31      Spain     Kagglazon
# 27371  164321  2022-12-31      Spain     Kagglazon
# 27372  164322  2022-12-31      Spain     Kagglazon
# 27373  164323  2022-12-31      Spain     Kagglazon
# 27374  164324  2022-12-31      Spain     Kagglazon
#
#                                               product
# 0                   Using LLMs to Improve Your Coding
# 1                       Using LLMs to Train More LLMs
# 2      Using LLMs to Win Friends and Influence People
# 3          Using LLMs to Win More Kaggle Competitions
# 4                          Using LLMs to Write Better
# ...                                               ...
# 27370               Using LLMs to Improve Your Coding
# 27371                   Using LLMs to Train More LLMs
# 27372  Using LLMs to Win Friends and Influence People
# 27373      Using LLMs to Win More Kaggle Competitions
# 27374                      Using LLMs to Write Better
#
# [27375 rows x 5 columns]

# %%
train_eng = pd.read_csv('train_engineered.csv')
train_eng
# Out:
#             id        date  num_sold  Year  Qtr  Month     Month_Sin  Day  \
# 0            0  2017-01-01        63  2017    1      1  5.000000e-01    1
# 1            1  2017-01-01        66  2017    1      1  5.000000e-01    1
# 2            2  2017-01-01         9  2017    1      1  5.000000e-01    1
# 3            3  2017-01-01        59  2017    1      1  5.000000e-01    1
# 4            4  2017-01-01        49  2017    1      1  5.000000e-01    1
# ...        ...         ...       ...   ...  ...    ...           ...  ...
# 136945  136945  2021-12-31       700  2021    4     12 -2.449294e-16   31
# 136946  136946  2021-12-31       752  2021    4     12 -2.449294e-16   31
# 136947  136947  2021-12-31       111  2021    4     12 -2.449294e-16   31
# 136948  136948  2021-12-31       641  2021    4     12 -2.449294e-16   31
# 136949  136949  2021-12-31       539  2021    4     12 -2.449294e-16   31
#
#         Day_Sin  Weekday  ...          sin2  cos2      IYC_sin2  IYC_cos2  \
# 0           0.5        6  ...  8.660254e-01   0.5  8.660254e-01       0.5
# 1           0.5        6  ...  8.660254e-01   0.5  0.000000e+00       0.0
# 2           0.5        6  ...  8.660254e-01   0.5  0.000000e+00       0.0
# 3           0.5        6  ...  8.660254e-01   0.5  0.000000e+00       0.0
# 4           0.5        6  ...  8.660254e-01   0.5  0.000000e+00       0.0
# ...         ...      ...  ...           ...   ...           ...       ...
# 136945     -0.5        4  ... -4.898587e-16   1.0 -4.898587e-16       1.0
# 136946     -0.5        4  ... -4.898587e-16   1.0 -0.000000e+00       0.0
# 136947     -0.5        4  ... -4.898587e-16   1.0 -0.000000e+00       0.0
# 136948     -0.5        4  ... -4.898587e-16   1.0 -0.000000e+00       0.0
# 136949     -0.5        4  ... -4.898587e-16   1.0 -0.000000e+00       0.0
#
#             TTL_sin2  TTL_cos2     WMKC_sin2  WMKC_cos2       WB_sin2  WB_cos2
# 0       0.000000e+00       0.0  0.000000e+00        0.0  0.000000e+00      0.0
# 1       8.660254e-01       0.5  0.000000e+00        0.0  0.000000e+00      0.0
# 2       0.000000e+00       0.0  0.000000e+00        0.0  0.000000e+00      0.0
# 3       0.000000e+00       0.0  8.660254e-01        0.5  0.000000e+00      0.0
# 4       0.000000e+00       0.0  0.000000e+00        0.0  8.660254e-01      0.5
# ...              ...       ...           ...        ...           ...      ...
# 136945 -0.000000e+00       0.0 -0.000000e+00        0.0 -0.000000e+00      0.0
# 136946 -4.898587e-16       1.0 -0.000000e+00        0.0 -0.000000e+00      0.0
# 136947 -0.000000e+00       0.0 -0.000000e+00        0.0 -0.000000e+00      0.0
# 136948 -0.000000e+00       0.0 -4.898587e-16        1.0 -0.000000e+00      0.0
# 136949 -0.000000e+00       0.0 -0.000000e+00        0.0 -4.898587e-16      1.0
#
# [136950 rows x 57 columns]

# %%
test_eng = pd.read_csv('test_engineered.csv')
test_eng
# Out:
#            id        date  Year  Qtr  Month     Month_Sin  Day  Day_Sin  \
# 0      136950  2022-01-01  2022    1      1  5.000000e-01    1      0.5
# 1      136951  2022-01-01  2022    1      1  5.000000e-01    1      0.5
# 2      136952  2022-01-01  2022    1      1  5.000000e-01    1      0.5
# 3      136953  2022-01-01  2022    1      1  5.000000e-01    1      0.5
# 4      136954  2022-01-01  2022    1      1  5.000000e-01    1      0.5
# ...       ...         ...   ...  ...    ...           ...  ...      ...
# 27370  164320  2022-12-31  2022    4     12 -2.449294e-16   31     -0.5
# 27371  164321  2022-12-31  2022    4     12 -2.449294e-16   31     -0.5
# 27372  164322  2022-12-31  2022    4     12 -2.449294e-16   31     -0.5
# 27373  164323  2022-12-31  2022    4     12 -2.449294e-16   31     -0.5
# 27374  164324  2022-12-31  2022    4     12 -2.449294e-16   31     -0.5
#
#        Weekday  Week_Nb  ...          sin2  cos2      IYC_sin2  IYC_cos2  \
# 0            5       52  ...  8.660254e-01   0.5  8.660254e-01       0.5
# 1            5       52  ...  8.660254e-01   0.5  0.000000e+00       0.0
# 2            5       52  ...  8.660254e-01   0.5  0.000000e+00       0.0
# 3            5       52  ...  8.660254e-01   0.5  0.000000e+00       0.0
# 4            5       52  ...  8.660254e-01   0.5  0.000000e+00       0.0
# ...        ...      ...  ...           ...   ...           ...       ...
# 27370        5       52  ... -4.898587e-16   1.0 -4.898587e-16       1.0
# 27371        5       52  ... -4.898587e-16   1.0 -0.000000e+00       0.0
# 27372        5       52  ... -4.898587e-16   1.0 -0.000000e+00       0.0
# 27373        5       52  ... -4.898587e-16   1.0 -0.000000e+00       0.0
# 27374        5       52  ... -4.898587e-16   1.0 -0.000000e+00       0.0
#
#            TTL_sin2  TTL_cos2     WMKC_sin2  WMKC_cos2       WB_sin2  WB_cos2
# 0      0.000000e+00       0.0  0.000000e+00        0.0  0.000000e+00      0.0
# 1      8.660254e-01       0.5  0.000000e+00        0.0  0.000000e+00      0.0
# 2      0.000000e+00       0.0  0.000000e+00        0.0  0.000000e+00      0.0
# 3      0.000000e+00       0.0  8.660254e-01        0.5  0.000000e+00      0.0
# 4      0.000000e+00       0.0  0.000000e+00        0.0  8.660254e-01      0.5
# ...             ...       ...           ...        ...           ...      ...
# 27370 -0.000000e+00       0.0 -0.000000e+00        0.0 -0.000000e+00      0.0
# 27371 -4.898587e-16       1.0 -0.000000e+00        0.0 -0.000000e+00      0.0
# 27372 -0.000000e+00       0.0 -0.000000e+00        0.0 -0.000000e+00      0.0
# 27373 -0.000000e+00       0.0 -4.898587e-16        1.0 -0.000000e+00      0.0
# 27374 -0.000000e+00       0.0 -0.000000e+00        0.0 -4.898587e-16      1.0
#
# [27375 rows x 56 columns]

# %%
train_data_ori.date = pd.to_datetime(train_data_ori.date)
test_data_ori.date = pd.to_datetime(test_data_ori.date)

# %% [markdown]
# ## Applying ensemble models

# %%
import catboost
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.metrics import make_scorer

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler

import optuna
np.random.seed(5)

# %%
smape = make_scorer(calculate_smape, greater_is_better = False)

# %%
X = train_eng.drop(['id','num_sold','date'], axis=1).astype('float')
y = np.log(train_eng['num_sold'].values).reshape(-1,1)

# %%
features = X.columns.to_list()
target = 'num_sold'

# %%
def eval_model(y_val, y_hat):
    plt.figure(figsize=(6, 6))
    plt.scatter(y_val, y_hat, s=1, color='r')
    plt.plot([plt.xlim()[0], plt.xlim()[1]], [plt.xlim()[0], plt.xlim()[1]], '--', color='k')
    plt.gca().set_aspect('equal')
    plt.xlabel('y_true')
    plt.ylabel('y_pred')
    plt.title('OOF Predictions')
    plt.show()
    
    residuals = np.log(y_hat) - np.log(y_val)
    
    plt.figure(figsize=(18, 4))
    plt.scatter(np.arange(len(residuals)), residuals, s=1)
    plt.title('All residuals by row number')
    plt.ylabel('residual')
    plt.show()
    
    plt.figure(figsize=(18, 4))
    plt.hist(residuals, bins=200)
    plt.title('Histogram of all residuals')
    plt.show()
    print(f"Standard deviation of log residuals: {residuals.std():.3f}")
    plt.show()

# %%
def train_model(model, params, evaluate=False):
    scores = []
    tscv = TimeSeriesSplit(n_splits=3, test_size=27390)
    for fold, (train_idx, val_idx) in enumerate(tscv.split(train_eng)):
        start_time = datetime.now()
        train = train_eng.iloc[train_idx]
        val = train_eng.iloc[val_idx]
        print('Training on these years', set(train.Year))
        print('Validating on these years', set(val.Year))  
        X_train = train[features]
        y_train = np.log(train[target])
        X_val = val[features]
        y_val = val[target]
        scaler = StandardScaler()
        X_tr_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        if model=='cbr':
            model = CatBoostRegressor(**params, random_state=5, verbose=0)
        elif model=='xgb':
            model = XGBRegressor(**params, random_state=5)
        elif model=='lgbm':
            model = LGBMRegressor(**params, random_state=5)
        model.fit(X_tr_scaled, y_train)

        y_hat = np.exp(model.predict(X_val_scaled))
    #     print(y_hat)
    #     oof.update(pd.Series(y_hat, index=X_val.index))
        smape_bc = calculate_smape(np.array(y_val),np.array(y_hat))
        smape_ac = calculate_smape(np.array(y_val),np.array(y_hat)/1.05)
    #     smape = calculate_smape(np.array(y_val)*1.25,np.array(y_hat))
        print(f"Fold {fold} | {str(datetime.now() - start_time)[-12:-7]}"
              f" | SMAPE BC: {smape_bc:.5f}| SMAPE AC: {smape_ac:.5f}")
    #      
        scores.append(smape_bc)
        if (fold==0)&(evaluate):
            eval_model(y_val, y_hat/1.05)
    return np.mean(scores), model

# %%
def run_model(model, n_trials=20):
    def objective(trial):
        # Define the hyperparameter search space
        if model=='cbr':
            params = {
                'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
                'n_estimators': trial.suggest_int('n_estimators', 100, 500, step=100),
                'depth': trial.suggest_int('depth', 4, 10),
                'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 1e2),
                'border_count': trial.suggest_int('border_count', 32, 255),
                'early_stopping_rounds': 10,  # Set a fixed value or use early stopping
                'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.5, 5)
            }
        if model=='xgb':
            params = {
                'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
                'n_estimators': trial.suggest_int('n_estimators', 100, 500, step=100),
                'max_depth': trial.suggest_int('max_depth', 4, 10),
                'gamma': trial.suggest_loguniform('gamma', 1e-3, 1),
                'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
                'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
                'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 10),
                'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-5, 10),
                'objective': 'reg:squarederror',
                'eval_metric': calculate_smape,
                'n_jobs': -1
            }
        smape, _ = train_model(model, params)
        return smape
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)
    best_params = study.best_params
    best_score = study.best_value
    print('The best parameters are:', best_params)
    print('The best SMAPE is:', best_score)
    return best_params

# %% [markdown]
# ## Catboost Regressor

# %%
best_params = run_model('cbr')
# Out:
# [I 2023-07-19 16:16:48,045] A new study created in memory with name: no-name-27602b2f-ccbc-4956-ad94-77d143959fab
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 35.64790| SMAPE AC: 35.54940
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 36.83070| SMAPE AC: 36.18860
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:17:00,756] Trial 0 finished with value: 35.68853333333333 and parameters: {'learning_rate': 0.011101530758360175, 'n_estimators': 100, 'depth': 10, 'l2_leaf_reg': 0.010860041570365374, 'border_count': 155, 'bagging_temperature': 2.59610701421254}. Best is trial 0 with value: 35.68853333333333.
# Fold 2 | 00:05 | SMAPE BC: 34.58700| SMAPE AC: 35.76940
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:12 | SMAPE BC: 11.93930| SMAPE AC: 10.92640
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:16 | SMAPE BC: 13.98790| SMAPE AC: 12.69840
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:17:49,114] Trial 1 finished with value: 12.618633333333333 and parameters: {'learning_rate': 0.1023508677821864, 'n_estimators': 400, 'depth': 10, 'l2_leaf_reg': 0.49093616655924766, 'border_count': 180, 'bagging_temperature': 0.5346426700650493}. Best is trial 1 with value: 12.618633333333333.
# Fold 2 | 00:19 | SMAPE BC: 11.92870| SMAPE AC: 14.87760
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:09 | SMAPE BC: 11.93450| SMAPE AC: 10.52070
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:12 | SMAPE BC: 13.74160| SMAPE AC: 12.50930
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:18:25,886] Trial 2 finished with value: 12.465033333333333 and parameters: {'learning_rate': 0.06908593401452874, 'n_estimators': 300, 'depth': 10, 'l2_leaf_reg': 0.3377177432985683, 'border_count': 229, 'bagging_temperature': 0.6002507474635372}. Best is trial 2 with value: 12.465033333333333.
# Fold 2 | 00:14 | SMAPE BC: 11.71900| SMAPE AC: 14.95390
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 10.78560| SMAPE AC: 9.49880
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 13.84410| SMAPE AC: 12.37650
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:18:38,256] Trial 3 finished with value: 12.068833333333332 and parameters: {'learning_rate': 0.08219394005947846, 'n_estimators': 200, 'depth': 9, 'l2_leaf_reg': 3.9869148669483714, 'border_count': 143, 'bagging_temperature': 1.271781523631387}. Best is trial 3 with value: 12.068833333333332.
# Fold 2 | 00:04 | SMAPE BC: 11.57680| SMAPE AC: 14.58070
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 8.81370| SMAPE AC: 7.98920
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:05 | SMAPE BC: 13.62120| SMAPE AC: 12.13360
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:18:53,678] Trial 4 finished with value: 11.405700000000001 and parameters: {'learning_rate': 0.07786182604270385, 'n_estimators': 500, 'depth': 5, 'l2_leaf_reg': 58.359853410192265, 'border_count': 33, 'bagging_temperature': 3.178369250587727}. Best is trial 4 with value: 11.405700000000001.
# Fold 2 | 00:06 | SMAPE BC: 11.78220| SMAPE AC: 14.55500
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 8.87220| SMAPE AC: 7.77770
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 12.13800| SMAPE AC: 10.72460
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:19:07,823] Trial 5 finished with value: 10.851266666666666 and parameters: {'learning_rate': 0.1641320867898628, 'n_estimators': 400, 'depth': 6, 'l2_leaf_reg': 0.03104886528782407, 'border_count': 232, 'bagging_temperature': 0.7988961001017277}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:05 | SMAPE BC: 11.54360| SMAPE AC: 14.73630
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 14.08320| SMAPE AC: 13.47930
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 17.00690| SMAPE AC: 15.81230
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:19:22,711] Trial 6 finished with value: 15.145433333333335 and parameters: {'learning_rate': 0.010237471699256229, 'n_estimators': 300, 'depth': 8, 'l2_leaf_reg': 0.9522514860764212, 'border_count': 157, 'bagging_temperature': 1.6655881264693155}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:06 | SMAPE BC: 14.34620| SMAPE AC: 16.41910
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:02 | SMAPE BC: 10.99470| SMAPE AC: 9.66050
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:02 | SMAPE BC: 13.33330| SMAPE AC: 11.89690
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:19:31,560] Trial 7 finished with value: 11.886066666666666 and parameters: {'learning_rate': 0.04418874424171931, 'n_estimators': 200, 'depth': 7, 'l2_leaf_reg': 1.7890430020989916, 'border_count': 57, 'bagging_temperature': 0.5127515115191267}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:03 | SMAPE BC: 11.33020| SMAPE AC: 13.99830
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 11.52090| SMAPE AC: 10.31680
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 13.75490| SMAPE AC: 12.24990
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:19:44,330] Trial 8 finished with value: 12.3685 and parameters: {'learning_rate': 0.02073819667341861, 'n_estimators': 300, 'depth': 7, 'l2_leaf_reg': 0.02952845777571162, 'border_count': 250, 'bagging_temperature': 4.0130094202591655}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:05 | SMAPE BC: 11.82970| SMAPE AC: 13.78380
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:15 | SMAPE BC: 12.39520| SMAPE AC: 11.34300
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:19 | SMAPE BC: 15.34600| SMAPE AC: 13.96100
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:20:42,933] Trial 9 finished with value: 12.984 and parameters: {'learning_rate': 0.11904400640649561, 'n_estimators': 500, 'depth': 10, 'l2_leaf_reg': 0.013386750113530733, 'border_count': 56, 'bagging_temperature': 0.9707452698233989}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:23 | SMAPE BC: 11.21080| SMAPE AC: 14.37020
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:02 | SMAPE BC: 9.13330| SMAPE AC: 7.72130
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:03 | SMAPE BC: 13.94520| SMAPE AC: 11.28570
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:20:54,298] Trial 10 finished with value: 11.297666666666666 and parameters: {'learning_rate': 0.1857616034568744, 'n_estimators': 400, 'depth': 4, 'l2_leaf_reg': 0.0010299124561854243, 'border_count': 207, 'bagging_temperature': 0.9349400867553875}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:04 | SMAPE BC: 10.81450| SMAPE AC: 12.94000
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:02 | SMAPE BC: 9.05340| SMAPE AC: 7.96640
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 13.17620| SMAPE AC: 11.27280
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:21:05,799] Trial 11 finished with value: 11.358533333333332 and parameters: {'learning_rate': 0.19686329831208094, 'n_estimators': 400, 'depth': 4, 'l2_leaf_reg': 0.0014379608968635368, 'border_count': 215, 'bagging_temperature': 0.918834802512018}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:04 | SMAPE BC: 11.84600| SMAPE AC: 14.72780
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 9.13200| SMAPE AC: 7.91830
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 13.21280| SMAPE AC: 11.25810
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:21:18,398] Trial 12 finished with value: 11.547400000000001 and parameters: {'learning_rate': 0.18268556681500897, 'n_estimators': 400, 'depth': 5, 'l2_leaf_reg': 0.0010392225697268085, 'border_count': 197, 'bagging_temperature': 0.8624410074291191}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:05 | SMAPE BC: 12.29740| SMAPE AC: 15.38500
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 9.58230| SMAPE AC: 8.38780
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 12.48440| SMAPE AC: 11.41710
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:21:32,124] Trial 13 finished with value: 11.145233333333332 and parameters: {'learning_rate': 0.19785877502891924, 'n_estimators': 400, 'depth': 6, 'l2_leaf_reg': 0.04378772840689785, 'border_count': 110, 'bagging_temperature': 1.7246990049027369}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:05 | SMAPE BC: 11.36900| SMAPE AC: 14.01470
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:04 | SMAPE BC: 9.22060| SMAPE AC: 7.97700
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:05 | SMAPE BC: 13.13920| SMAPE AC: 11.00260
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:21:49,066] Trial 14 finished with value: 11.203966666666666 and parameters: {'learning_rate': 0.12060447872494266, 'n_estimators': 500, 'depth': 6, 'l2_leaf_reg': 0.0618653179366239, 'border_count': 105, 'bagging_temperature': 1.8768336918399904}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:07 | SMAPE BC: 11.25210| SMAPE AC: 13.58350
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 9.07040| SMAPE AC: 7.87250
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 13.26130| SMAPE AC: 12.10710
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:22:03,117] Trial 15 finished with value: 11.092733333333333 and parameters: {'learning_rate': 0.14444944480155028, 'n_estimators': 400, 'depth': 6, 'l2_leaf_reg': 0.061468096134041986, 'border_count': 114, 'bagging_temperature': 2.1713760412290366}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:05 | SMAPE BC: 10.94650| SMAPE AC: 13.39430
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:02 | SMAPE BC: 10.23100| SMAPE AC: 8.46250
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:02 | SMAPE BC: 13.51370| SMAPE AC: 12.51280
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:22:11,237] Trial 16 finished with value: 11.733366666666667 and parameters: {'learning_rate': 0.05374168090142982, 'n_estimators': 200, 'depth': 6, 'l2_leaf_reg': 0.1561917283057934, 'border_count': 106, 'bagging_temperature': 2.3385033273256446}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:03 | SMAPE BC: 11.45540| SMAPE AC: 14.36500
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:05 | SMAPE BC: 9.26660| SMAPE AC: 8.15130
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:07 | SMAPE BC: 13.35730| SMAPE AC: 12.00040
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:22:34,147] Trial 17 finished with value: 11.4758 and parameters: {'learning_rate': 0.14523942137563153, 'n_estimators': 500, 'depth': 8, 'l2_leaf_reg': 0.00605512333579543, 'border_count': 129, 'bagging_temperature': 4.729123568524475}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:09 | SMAPE BC: 11.80350| SMAPE AC: 15.29260
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:02 | SMAPE BC: 9.26960| SMAPE AC: 8.26670
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:03 | SMAPE BC: 14.66540| SMAPE AC: 12.32990
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:22:43,901] Trial 18 finished with value: 12.083166666666669 and parameters: {'learning_rate': 0.10149323582835271, 'n_estimators': 300, 'depth': 5, 'l2_leaf_reg': 0.04484839894662069, 'border_count': 84, 'bagging_temperature': 1.3723895396501613}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:04 | SMAPE BC: 12.31450| SMAPE AC: 15.27650
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:04 | SMAPE BC: 9.31360| SMAPE AC: 8.11150
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:05 | SMAPE BC: 13.25750| SMAPE AC: 11.94080
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 16:23:02,826] Trial 19 finished with value: 11.528866666666667 and parameters: {'learning_rate': 0.13923953485552257, 'n_estimators': 400, 'depth': 8, 'l2_leaf_reg': 0.13068996220015353, 'border_count': 176, 'bagging_temperature': 2.1164194917811945}. Best is trial 5 with value: 10.851266666666666.
# Fold 2 | 00:08 | SMAPE BC: 12.01550| SMAPE AC: 15.54800
# The best parameters are: {'learning_rate': 0.1641320867898628, 'n_estimators': 400, 'depth': 6, 'l2_leaf_reg': 0.03104886528782407, 'border_count': 232, 'bagging_temperature': 0.7988961001017277}
# The best SMAPE is: 10.851266666666666

# %%
_, cb_model = train_model('cbr', best_params, True)
# Out:
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 8.87220| SMAPE AC: 7.77770
# Standard deviation of log residuals: 0.100
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 12.13800| SMAPE AC: 10.72460
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# Fold 2 | 00:06 | SMAPE BC: 11.54360| SMAPE AC: 14.73630

# %%
# make predictions
y_hat = np.exp(cb_model.predict(test_eng[features]))
y_hat
# Out:
# array([ 73.30163212,  80.44425214,  41.41584561, ..., 103.20464509,
#        589.95216856, 534.48856662])

# %%
sub = pd.DataFrame(zip(test_eng.id,y_hat), columns=['id','num_sold'])
sub
# Out:
#            id    num_sold
# 0      136950   73.301632
# 1      136951   80.444252
# 2      136952   41.415846
# 3      136953   72.979811
# 4      136954   67.841371
# ...       ...         ...
# 27370  164320  610.295741
# 27371  164321  662.679143
# 27372  164322  103.204645
# 27373  164323  589.952169
# 27374  164324  534.488567
#
# [27375 rows x 2 columns]

# %%
sub.to_csv('submissions/sub17.csv', index=False)

# %% [markdown]
# ## XGBoost Regressor

# %%
best_params = run_model('xgb', 10)
# Out:
# [I 2023-07-19 15:44:41,951] A new study created in memory with name: no-name-f182b80f-fa3e-4f1d-b0a2-cc36ab0093a8
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:27 | SMAPE BC: 8.47900| SMAPE AC: 8.26850
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:40 | SMAPE BC: 11.30660| SMAPE AC: 9.56910
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:46:43,509] Trial 0 finished with value: 11.9621 and parameters: {'learning_rate': 0.040797801384601484, 'n_estimators': 500, 'max_depth': 10, 'gamma': 0.09779394038785559, 'subsample': 0.9083844801037135, 'colsample_bytree': 0.8158335363943221, 'reg_alpha': 0.004027467186345932, 'reg_lambda': 0.4231721353476409}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:53 | SMAPE BC: 16.10070| SMAPE AC: 19.54990
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:08 | SMAPE BC: 9.14290| SMAPE AC: 8.12560
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:12 | SMAPE BC: 12.67220| SMAPE AC: 10.39540
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:47:19,933] Trial 1 finished with value: 12.918300000000002 and parameters: {'learning_rate': 0.17052679559266168, 'n_estimators': 200, 'max_depth': 8, 'gamma': 0.005511810581985553, 'subsample': 0.9189620342494088, 'colsample_bytree': 0.749250737642472, 'reg_alpha': 2.8459371695819807e-05, 'reg_lambda': 2.4338367141373557e-05}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:15 | SMAPE BC: 16.93980| SMAPE AC: 20.43570
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:13 | SMAPE BC: 9.99870| SMAPE AC: 8.94470
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:20 | SMAPE BC: 13.10970| SMAPE AC: 10.97430
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:48:22,322] Trial 2 finished with value: 13.113166666666666 and parameters: {'learning_rate': 0.02365019742765162, 'n_estimators': 300, 'max_depth': 8, 'gamma': 0.869377194339741, 'subsample': 0.9063508199061303, 'colsample_bytree': 0.9223141975966762, 'reg_alpha': 0.00026221881721440426, 'reg_lambda': 0.17087404229961067}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:27 | SMAPE BC: 16.23110| SMAPE AC: 19.65770
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:29 | SMAPE BC: 9.69320| SMAPE AC: 8.54290
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:44 | SMAPE BC: 12.80410| SMAPE AC: 10.45320
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:50:33,600] Trial 3 finished with value: 12.952566666666664 and parameters: {'learning_rate': 0.041171612823783586, 'n_estimators': 400, 'max_depth': 10, 'gamma': 0.007579051690062705, 'subsample': 0.6028596944289549, 'colsample_bytree': 0.9020078074322586, 'reg_alpha': 0.023202071127000234, 'reg_lambda': 0.061131010889955324}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:58 | SMAPE BC: 16.36040| SMAPE AC: 19.80380
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:18 | SMAPE BC: 10.01180| SMAPE AC: 8.77320
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:28 | SMAPE BC: 13.17350| SMAPE AC: 10.86110
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:51:59,435] Trial 4 finished with value: 13.289766666666665 and parameters: {'learning_rate': 0.03018984909372051, 'n_estimators': 300, 'max_depth': 9, 'gamma': 0.3530825573283432, 'subsample': 0.7241994987663127, 'colsample_bytree': 0.9521848953038919, 'reg_alpha': 0.0009535491698602652, 'reg_lambda': 0.0021641939572601596}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:39 | SMAPE BC: 16.68400| SMAPE AC: 20.10250
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:25 | SMAPE BC: 10.02340| SMAPE AC: 8.84480
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:37 | SMAPE BC: 13.05820| SMAPE AC: 10.81470
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:53:53,257] Trial 5 finished with value: 12.948 and parameters: {'learning_rate': 0.03270828747342562, 'n_estimators': 400, 'max_depth': 10, 'gamma': 0.44838554955998405, 'subsample': 0.6724684316970768, 'colsample_bytree': 0.761959578273937, 'reg_alpha': 0.03673763557943964, 'reg_lambda': 7.447784632920019e-05}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:50 | SMAPE BC: 15.76240| SMAPE AC: 19.28710
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:14 | SMAPE BC: 9.78660| SMAPE AC: 8.74390
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:22 | SMAPE BC: 12.66980| SMAPE AC: 10.67130
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:54:59,361] Trial 6 finished with value: 12.732833333333334 and parameters: {'learning_rate': 0.09544307547860971, 'n_estimators': 300, 'max_depth': 9, 'gamma': 0.6346928545283873, 'subsample': 0.7713496480767882, 'colsample_bytree': 0.7317661065027645, 'reg_alpha': 0.02678475324067889, 'reg_lambda': 0.0001580712511757475}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:29 | SMAPE BC: 15.74210| SMAPE AC: 19.35760
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:05 | SMAPE BC: 17.31180| SMAPE AC: 20.70860
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:08 | SMAPE BC: 14.66130| SMAPE AC: 17.36420
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:55:25,028] Trial 7 finished with value: 21.633633333333336 and parameters: {'learning_rate': 0.02924735523112266, 'n_estimators': 100, 'max_depth': 9, 'gamma': 0.04640040909915825, 'subsample': 0.7761287705404271, 'colsample_bytree': 0.8801655155594683, 'reg_alpha': 1.404388138429211e-05, 'reg_lambda': 0.0013406836237976508}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:11 | SMAPE BC: 32.92780| SMAPE AC: 37.59610
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:32 | SMAPE BC: 8.26990| SMAPE AC: 7.94740
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:47 | SMAPE BC: 11.63300| SMAPE AC: 9.79550
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:57:48,654] Trial 8 finished with value: 12.146499999999998 and parameters: {'learning_rate': 0.09004151389718887, 'n_estimators': 500, 'max_depth': 9, 'gamma': 0.10636652965106155, 'subsample': 0.6363776840683106, 'colsample_bytree': 0.9365712386111082, 'reg_alpha': 0.00031263529830944205, 'reg_lambda': 0.049037352011851824}. Best is trial 0 with value: 11.9621.
# Fold 2 | 01:03 | SMAPE BC: 16.53660| SMAPE AC: 19.99240
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:03 | SMAPE BC: 9.74440| SMAPE AC: 8.48770
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:04 | SMAPE BC: 13.11170| SMAPE AC: 10.81200
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# [I 2023-07-19 15:58:03,094] Trial 9 finished with value: 12.640233333333335 and parameters: {'learning_rate': 0.08837033672211661, 'n_estimators': 100, 'max_depth': 6, 'gamma': 0.11852563504868424, 'subsample': 0.9159957268408898, 'colsample_bytree': 0.7777451156878252, 'reg_alpha': 0.06820948581305282, 'reg_lambda': 0.2784400528289632}. Best is trial 0 with value: 11.9621.
# Fold 2 | 00:06 | SMAPE BC: 15.06460| SMAPE AC: 18.49740
# The best parameters are: {'learning_rate': 0.040797801384601484, 'n_estimators': 500, 'max_depth': 10, 'gamma': 0.09779394038785559, 'subsample': 0.9083844801037135, 'colsample_bytree': 0.8158335363943221, 'reg_alpha': 0.004027467186345932, 'reg_lambda': 0.4231721353476409}
# The best SMAPE is: 11.9621

# %%
train_model('xgb', best_params, True)
# Out:
# Training on these years {2017, 2018, 2019}
# Validating on these years {2019, 2020}
# Fold 0 | 00:31 | SMAPE BC: 8.47900| SMAPE AC: 8.26850
# Standard deviation of log residuals: 0.105
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020}
# Fold 1 | 00:46 | SMAPE BC: 11.30660| SMAPE AC: 9.56910
# Training on these years {2017, 2018, 2019, 2020}
# Validating on these years {2020, 2021}
# Fold 2 | 00:54 | SMAPE BC: 16.10070| SMAPE AC: 19.54990
# 11.9621

# %% [markdown]
# ## LightGBM Regressor
